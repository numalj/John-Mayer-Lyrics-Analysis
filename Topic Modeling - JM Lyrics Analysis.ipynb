# %% [markdown]
# # Topic Modeling

# %% [markdown]
# ## Introduction

# %% [markdown]
# Since I've looked at the sentiment of the lyrics, now I'll try another popular text analysis technique called topic modeling. Topic modeling helps identify various topics in the text (corpus). Each document in the corpus will be made up of at least one topic, but can also be made of multiple topics.
#
# As an initial attempt, I decided to do Topic Modeling using **Latent Dirichlet Allocation (LDA)**, which is one of many topic modeling techniques. I chose this because it is able to put weight on a sinlge topic when there is a mix of topics and also seemed easy to implement. It was specifically designed for text data.
#
# To use a topic modeling technique, you need to provide (1) a document-term matrix and (2) the number of topics you would like the algorithm to pick up.
#
# LDA is an unsupervised algorithm. This means that once LDA is applied, the user has interpret the results and decide whether the words in each topic make sense. Ideally the words in each topic should have a common theme/topic, making it a... TOPIC! But sometimes the words just seem random and so you would have to can try changing the number of topics, the terms in the document-term matrix or if nothing seems to work, try a different model.

# %% [markdown]
# ## Topic Modeling - Attempt #1 (All Songs)

# %%
# Let's read in our document-term matrix
import pandas as pd
import pickle

data = pd.read_pickle('lyrics/song_dtm_stop.pkl')
data
# Out:
#                                    accepted  act  actors  address  adore  \
# Title
# No Such Thing                             0    0       0        0      0
# Why Georgia                               0    0       0        0      0
# My Stupid Mouth                           0    0       0        0      0
# Your Body Is A Wonderland                 0    0       0        0      0
# Neon                                      0    0       0        0      0
# ...                                     ...  ...     ...      ...    ...
# "Moving On and Getting Over"              0    0       0        0      0
# "Never on the Day You Leave"              0    0       0        0      0
# "Rosie"                                   0    0       0        0      0
# "Roll It on Home"                         0    0       0        0      0
# "You're Gonna Live Forever in Me"         0    0       0        0      0
#
#                                    advice  affair  afternoon  age  ago  ...  \
# Title                                                                   ...
# No Such Thing                           0       0          0    0    0  ...
# Why Georgia                             0       0          1    0    0  ...
# My Stupid Mouth                         0       0          0    0    0  ...
# Your Body Is A Wonderland               0       0          1    0    0  ...
# Neon                                    0       0          0    0    0  ...
# ...                                   ...     ...        ...  ...  ...  ...
# "Moving On and Getting Over"            0       0          0    0    0  ...
# "Never on the Day You Leave"            0       0          0    0    0  ...
# "Rosie"                                 0       0          0    0    0  ...
# "Roll It on Home"                       0       0          0    0    0  ...
# "You're Gonna Live Forever in Me"       0       0          0    0    0  ...
#
#                                    yellow  yes  yesterday  york  youd  youll  \
# Title
# No Such Thing                           0    0          0     0     0      0
# Why Georgia                             0    0          0     0     0      0
# My Stupid Mouth                         0    0          1     0     0      0
# Your Body Is A Wonderland               0    0          0     0     0      0
# Neon                                    0    0          0     0     0      0
# ...                                   ...  ...        ...   ...   ...    ...
# "Moving On and Getting Over"            0    0          0     0     0      0
# "Never on the Day You Leave"            0    0          0     0     1      2
# "Rosie"                                 0    0          0     0     0      0
# "Roll It on Home"                       0    0          1     0     0      0
# "You're Gonna Live Forever in Me"       0    0          0     0     0      0
#
#                                    young  younger  youre  youve
# Title
# No Such Thing                          0        0      0      3
# Why Georgia                            0        0      0      0
# My Stupid Mouth                        0        0      0      0
# Your Body Is A Wonderland              0        0      1      0
# Neon                                   0        0      0      0
# ...                                  ...      ...    ...    ...
# "Moving On and Getting Over"           0        0      0      2
# "Never on the Day You Leave"           0        0      0      0
# "Rosie"                                0        0      0      0
# "Roll It on Home"                      0        0      0      1
# "You're Gonna Live Forever in Me"      0        0      4      0
#
# [81 rows x 1490 columns]

# %%
# Import the necessary modules for LDA with gensim
# Terminal / Anaconda Navigator: conda install -c conda-forge gensim
from gensim import matutils, models
import scipy.sparse
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %%
# One of the required inputs is a term-document matrix
tdm = data.transpose()
tdm.head()
# Out:
# Title     No Such Thing  Why Georgia  My Stupid Mouth  \
# accepted              0            0                0
# act                   0            0                0
# actors                0            0                0
# address               0            0                0
# adore                 0            0                0
#
# Title     Your Body Is A Wonderland  Neon  City Love  83  3X5  \
# accepted                          0     0          0   0    0
# act                               0     0          0   0    0
# actors                            0     0          0   1    0
# address                           0     0          0   0    0
# adore                             0     0          0   0    0
#
# Title     Love Song For No One  Back To You  ...  "Helpless"  \
# accepted                     0            0  ...           0
# act                          0            0  ...           0
# actors                       0            0  ...           0
# address                      0            0  ...           0
# adore                        0            0  ...           0
#
# Title     "Love on the Weekend"  "In the Blood"  "Changing"  \
# accepted                      0               0           0
# act                           0               0           0
# actors                        0               0           0
# address                       0               0           0
# adore                         0               0           0
#
# Title     "Theme from "The Search for Everything""  \
# accepted                                         0
# act                                              0
# actors                                           0
# address                                          0
# adore                                            0
#
# Title     "Moving On and Getting Over"  "Never on the Day You Leave"  "Rosie"  \
# accepted                             0                             0        0
# act                                  0                             0        0
# actors                               0                             0        0
# address                              0                             0        0
# adore                                0                             0        0
#
# Title     "Roll It on Home"  "You're Gonna Live Forever in Me"
# accepted                  0                                  0
# act                       0                                  0
# actors                    0                                  0
# address                   0                                  0
# adore                     0                                  0
#
# [5 rows x 81 columns]

# %%
# We're going to put the term-document matrix into a new gensim format, from df --> sparse matrix --> gensim corpus
# Contains the term and count of each term
sparse_counts = scipy.sparse.csr_matrix(tdm)
corpus = matutils.Sparse2Corpus(sparse_counts)

# %%
# Gensim also requires dictionary of the all terms and their respective location in the term-document matrix
cv = pickle.load(open("lyrics/cv_s_stop.pkl", "rb"))
id2word = dict((v, k) for k, v in cv.vocabulary_.items())

# %%
# id2word is a dictionary that indexes each word
id2word
# Out:
# {1420: 'welcome',
#  973: 'real',
#  1464: 'world',
#  1040: 'said',
#  217: 'condescendingly',
#  1069: 'seat',
#  697: 'life',
#  915: 'plot',
#  92: 'black',
#  1431: 'white',
#  713: 'lived',
#  324: 'dreams',
#  936: 'prom',
#  661: 'kings',
#  316: 'drama',
#  953: 'queens',
#  608: 'id',
#  1288: 'think',
#  82: 'best',
#  575: 'hiding',
#  1139: 'sleeve',
#  734: 'love',
#  1272: 'tell',
#  1196: 'stay',
#  625: 'inside',
#  705: 'lines',
#  1164: 'somethings',
#  84: 'better',
#  1390: 'want',
#  1033: 'run',
#  529: 'halls',
#  576: 'high',
#  1058: 'school',
#  1060: 'scream',
#  743: 'lungs',
#  1282: 'theres',
#  1286: 'thing',
#  696: 'lie',
#  1489: 'youve',
#  1011: 'rise',
#  493: 'good',
#  114: 'boys',
#  476: 'girls',
#  146: 'called',
#  1008: 'right',
#  1326: 'track',
#  377: 'faded',
#  547: 'hats',
#  500: 'grabbing',
#  241: 'credits',
#  762: 'maybe',
#  1331: 'transfers',
#  971: 'read',
#  106: 'books',
#  23: 'answers',
#  873: 'parents',
#  1284: 'theyre',
#  472: 'getting',
#  846: 'older',
#  1455: 'wonder',
#  1285: 'theyve',
#  1449: 'wished',
#  773: 'memories',
#  1308: 'tiny',
#  1328: 'tragedies',
#  628: 'invincible',
#  722: 'long',
#  14: 'alive',
#  1375: 'wait',
#  1304: 'til',
#  1477: 'year',
#  999: 'reunion',
#  488: 'going',
#  141: 'bust',
#  313: 'double',
#  311: 'doors',
#  1187: 'stand',
#  1260: 'tables',
#  1305: 'time',
#  332: 'driving',
#  660: 'kind',
#  805: 'morning',
#  674: 'lasts',
#  7: 'afternoon',
#  1227: 'stuck',
#  483: 'gloom',
#  369: 'exits',
#  26: 'apartment',
#  1273: 'tempted',
#  155: 'car',
#  330: 'drive',
#  683: 'leave',
#  858: 'outcome',
#  1370: 'verdictless',
#  715: 'living',
#  469: 'georgia',
#  991: 'rent',
#  1023: 'room',
#  1172: 'spaces',
#  1459: 'wood',
#  905: 'places',
#  750: 'make',
#  401: 'feel',
#  587: 'home',
#  403: 'feels',
#  951: 'quarter',
#  242: 'crisis',
#  1204: 'stirring',
#  1169: 'soul',
#  1410: 'wayi',
#  635: 'ive',
#  1149: 'smile',
#  955: 'quiet',
#  1243: 'superstitions',
#  549: 'head',
#  308: 'dont',
#  73: 'believe',
#  1051: 'say',
#  363: 'everybody',
#  1216: 'stranger',
#  1280: 'thats',
#  255: 'danger',
#  1409: 'way',
#  521: 'guess',
#  933: 'price',
#  883: 'pay',
#  536: 'happens',
#  976: 'reason',
#  34: 'ask',
#  1229: 'stupid',
#  810: 'mouth',
#  1340: 'trouble',
#  260: 'date',
#  290: 'dinner',
#  1482: 'yesterday',
#  841: 'offended',
#  339: 'dying',
#  1230: 'subject',
#  172: 'change',
#  1156: 'social',
#  162: 'casualty',
#  1059: 'score',
#  445: 'forget',
#  755: 'mama',
#  1174: 'speaking',
#  414: 'filter',
#  1425: 'whats',
#  113: 'boy',
#  1167: 'soon',
#  89: 'bit',
#  708: 'lips',
#  725: 'looked',
#  1440: 'window',
#  1021: 'rolling',
#  51: 'balls',
#  818: 'napkin',
#  871: 'paper',
#  913: 'played',
#  954: 'quick',
#  463: 'game',
#  181: 'chess',
#  1042: 'salt',
#  889: 'pepper',
#  1091: 'shaker',
#  192: 'clearly',
#  618: 'indelible',
#  704: 'line',
#  319: 'drawn',
#  1143: 'slipped',
#  1421: 'went',
#  1472: 'wrong',
#  173: 'changed',
#  1279: 'thanks',
#  914: 'playing',
#  1344: 'try',
#  607: 'hurts',
#  815: 'mystery',
#  277: 'desert',
#  1193: 'starting',
#  395: 'fault',
#  538: 'hard',
#  279: 'desire',
#  703: 'liked',
#  459: 'funny',
#  727: 'looks',
#  644: 'jokes',
#  154: 'captain',
#  47: 'backfire',
#  688: 'left',
#  297: 'discover',
#  298: 'discovering',
#  785: 'mile',
#  616: 'inch',
#  1135: 'skin',
#  920: 'porcelain',
#  869: 'pair',
#  151: 'candy',
#  134: 'bubblegum',
#  1315: 'tongue',
#  1257: 'swim',
#  271: 'deep',
#  1063: 'sea',
#  94: 'blankets',
#  85: 'big',
#  910: 'plans',
#  117: 'break',
#  345: 'em',
#  111: 'bound',
#  102: 'body',
#  1457: 'wonderland',
#  611: 'ill',
#  1366: 'use',
#  532: 'hands',
#  112: 'bout',
#  525: 'hair',
#  385: 'falls',
#  375: 'face',
#  1093: 'shape',
#  238: 'crawling',
#  901: 'pillowcase',
#  690: 'let',
#  582: 'hit',
#  64: 'bed',
#  531: 'hand',
#  1173: 'speak',
#  251: 'damn',
#  46: 'baby',
#  457: 'frustrate',
#  1488: 'youre',
#  724: 'look',
#  1136: 'sky',
#  101: 'blue',
#  471: 'gets',
#  258: 'dark',
#  208: 'colors',
#  190: 'city',
#  702: 'lights',
#  1329: 'trail',
#  1031: 'ruby',
#  981: 'red',
#  285: 'diamond',
#  583: 'hits',
#  1241: 'sunrise',
#  210: 'comes',
#  486: 'goes',
#  1316: 'tonight',
#  1099: 'shes',
#  729: 'lose',
#  885: 'peachtree',
#  1221: 'street',
#  797: 'mixed',
#  329: 'drinks',
#  1269: 'techno',
#  62: 'beats',
#  561: 'heavy',
#  668: 'knows',
#  1144: 'slipping',
#  143: 'buzzing',
#  821: 'neon',
#  140: 'burns',
#  43: 'away',
#  20: 'angel',
#  904: 'place',
#  584: 'hold',
#  27: 'apple',
#  1321: 'touch',
#  985: 'remember',
#  149: 'came',
#  744: 'lydia',
#  650: 'keeps',
#  1319: 'toothbrush',
#  373: 'extra',
#  1171: 'space',
#  1200: 'steals',
#  201: 'clothes',
#  1413: 'wear',
#  1462: 'work',
#  526: 'hairs',
#  1102: 'shirts',
#  263: 'day',
#  234: 'covered',
#  964: 'rain',
#  291: 'dinnertime',
#  1088: 'shadowing',
#  1182: 'spun',
#  1179: 'spooned',
#  664: 'knew',
#  451: 'friday',
#  361: 'evening',
#  1423: 'weve',
#  328: 'drinking',
#  1253: 'swear',
#  939: 'propose',
#  196: 'close',
#  1259: 'tab',
#  1178: 'split',
#  144: 'cab',
#  384: 'falling',
#  37: 'asleep',
#  1170: 'sound',
#  1130: 'sirens',
#  60: 'battery',
#  462: 'gallery',
#  1057: 'scented',
#  484: 'glossy',
#  748: 'magazines',
#  1383: 'walking',
#  1367: 'used',
#  455: 'frozen',
#  404: 'feet',
#  1147: 'small',
#  1022: 'romanticizing',
#  1478: 'years',
#  9: 'ago',
#  91: 'bitter',
#  1255: 'sweet',
#  402: 'feeling',
#  553: 'hearing',
#  1468: 'wrapped',
#  417: 'finger',
#  961: 'radio',
#  265: 'days',
#  1448: 'wish',
#  153: 'cape',
#  1242: 'superman',
#  1287: 'things',
#  1191: 'start',
#  557: 'heaven',
#  1290: 'thinking',
#  130: 'brother',
#  80: 'ben',
#  790: 'miss',
#  643: 'john',
#  800: 'month',
#  275: 'delay',
#  1152: 'smiling',
#  1055: 'scared',
#  566: 'hell',
#  1079: 'sequel',
#  812: 'movie',
#  2: 'actors',
#  817: 'names',
#  356: 'escaped',
#  220: 'confused',
#  558: 'heavens',
#  1073: 'send',
#  928: 'prayers',
#  158: 'care',
#  867: 'paint',
#  600: 'house',
#  965: 'rainbow',
#  1010: 'rip',
#  433: 'floorboards',
#  995: 'replace',
#  1114: 'shutters',
#  911: 'plastic',
#  293: 'dirt',
#  535: 'happened',
#  742: 'lunchbox',
#  1297: 'thrown',
#  270: 'decision',
#  1471: 'writing',
#  164: 'catch',
#  565: 'held',
#  692: 'letter',
#  935: 'probably',
#  366: 'excited',
#  287: 'didnt',
#  150: 'camera',
#  593: 'hoping',
#  374: 'eyes',
#  802: 'mood',
#  1461: 'words',
#  1310: 'today',
#  1134: 'skies',
#  868: 'painted',
#  235: 'cowboy',
#  193: 'cliche',
#  1215: 'strange',
#  202: 'clouds',
#  809: 'mountains',
#  1072: 'seen',
#  132: 'brought',
#  1485: 'youll',
#  859: 'outside',
#  415: 'finally',
#  860: 'overcame',
#  1346: 'trying',
#  421: 'fit',
#  898: 'picture',
#  449: 'frame',
#  1197: 'staying',
#  428: 'flat',
#  432: 'floor',
#  726: 'looking',
#  845: 'old',
#  669: 'lack',
#  1281: 'thereof',
#  245: 'crushes',
#  1450: 'wishful',
#  636: 'jaded',
#  545: 'hate',
#  1309: 'tired',
#  605: 'hurry',
#  1066: 'searching',
#  1246: 'sure',
#  574: 'hide',
#  65: 'bedroom',
#  827: 'night',
#  1470: 'write',
#  1165: 'song',
#  779: 'met',
#  1044: 'sandbox',
#  877: 'passed',
#  1115: 'sidewalk',
#  791: 'missed',
#  170: 'chance',
#  1403: 'watched',
#  1382: 'walk',
#  1476: 'yeah',
#  1335: 'tried',
#  675: 'late',
#  446: 'forgetting',
#  957: 'quit',
#  912: 'play',
#  447: 'forgive',
#  1349: 'turn',
#  1087: 'shadow',
#  1138: 'sleeping',
#  1121: 'silhouette',
#  1150: 'smiled',
#  700: 'light',
#  305: 'doesnt',
#  1054: 'scare',
#  1226: 'strong',
#  178: 'check',
#  945: 'pulse',
#  938: 'proof',
#  710: 'listening',
#  699: 'lifes',
#  632: 'issuing',
#  1004: 'rhythm',
#  609: 'idle',
#  372: 'explore',
#  942: 'pull',
#  1086: 'shades',
#  1387: 'wander',
#  508: 'great',
#  619: 'indoors',
#  671: 'lamplight',
#  752: 'makes',
#  1089: 'shadows',
#  923: 'posters',
#  1385: 'walls',
#  1353: 'tv',
#  870: 'pane',
#  1372: 'view',
#  1458: 'wont',
#  381: 'faith',
#  83: 'bet',
#  276: 'depends',
#  390: 'far',
#  175: 'channel',
#  837: 'numbers',
#  676: 'lately',
#  93: 'blame',
#  1362: 'unlock',
#  310: 'door',
#  1244: 'suppose',
#  71: 'behavior',
#  1306: 'times',
#  1465: 'worried',
#  786: 'mind',
#  918: 'poetry',
#  940: 'prose',
#  209: 'come',
#  1049: 'saving',
#  501: 'grace',
#  204: 'cold',
#  1444: 'winter',
#  353: 'enter',
#  179: 'cheeks',
#  1085: 'shade',
#  903: 'pink',
#  997: 'rest',
#  926: 'powder',
#  520: 'guarantee',
#  834: 'november',
#  494: 'goodbye',
#  269: 'december',
#  838: 'obvious',
#  1393: 'wants',
#  188: 'christmas',
#  895: 'phone',
#  131: 'brothers',
#  396: 'favorite',
#  682: 'learning',
#  1154: 'snows',
#  1064: 'search',
#  185: 'children',
#  637: 'january',
#  753: 'making',
#  823: 'new',
#  996: 'resolutions',
#  399: 'february',
#  1368: 'valentine',
#  1039: 'safe',
#  1184: 'st',
#  881: 'patricks',
#  1006: 'ride',
#  1324: 'town',
#  63: 'beautiful',
#  601: 'houses',
#  573: 'hey',
#  466: 'gave',
#  1160: 'someday',
#  16: 'alright',
#  1466: 'worry',
#  1418: 'weigh',
#  1296: 'throw',
#  397: 'fear',
#  148: 'calm',
#  371: 'explain',
#  1017: 'rock',
#  152: 'candys',
#  772: 'melted',
#  286: 'diamonds',
#  983: 'remain',
#  852: 'oooooo',
#  980: 'recognize',
#  798: 'moment',
#  491: 'gone',
#  81: 'bend',
#  931: 'pretending',
#  706: 'lingered',
#  496: 'gots',
#  444: 'forever',
#  1245: 'supposed',
#  1070: 'second',
#  1041: 'sail',
#  333: 'drop',
#  19: 'anchor',
#  662: 'kiss',
#  514: 'ground',
#  1401: 'wasted',
#  1037: 'sacred',
#  649: 'june',
#  968: 'rainy',
#  1414: 'weather',
#  1400: 'waste',
#  984: 'remaining',
#  714: 'lives',
#  207: 'colorblind',
#  629: 'iou',
#  1213: 'stranded',
#  594: 'horizon',
#  1302: 'tied',
#  1341: 'true',
#  1481: 'yes',
#  515: 'grounded',
#  1442: 'wings',
#  194: 'clipped',
#  1249: 'surrounded',
#  882: 'pavement',
#  189: 'circle',
#  1378: 'waiting',
#  460: 'fuse',
#  337: 'dry',
#  435: 'fly',
#  1155: 'soar',
#  166: 'cause',
#  86: 'bigger',
#  478: 'gives',
#  240: 'credit',
#  680: 'learn',
#  1095: 'shed',
#  1338: 'tripping',
#  958: 'quite',
#  998: 'return',
#  1266: 'tangle',
#  927: 'power',
#  1071: 'seconds',
#  481: 'gladly',
#  424: 'flame',
#  425: 'flames',
#  1262: 'takes',
#  452: 'friend',
#  303: 'dizzy',
#  1104: 'shopping',
#  754: 'mall',
#  1065: 'searched',
#  646: 'joy',
#  110: 'bought',
#  568: 'help',
#  603: 'hunger',
#  866: 'pains',
#  1291: 'thirst',
#  334: 'drown',
#  1046: 'satiate',
#  792: 'missing',
#  422: 'fix',
#  41: 'autumn',
#  1384: 'walks',
#  1194: 'starts',
#  437: 'fog',
#  482: 'glass',
#  1237: 'summer',
#  554: 'heart',
#  1195: 'state',
#  278: 'design',
#  862: 'overthecounter',
#  1274: 'test',
#  720: 'loneliness',
#  288: 'different',
#  453: 'friends',
#  799: 'money',
#  1140: 'slept',
#  855: 'opposite',
#  1084: 'sex',
#  522: 'guitar',
#  782: 'microphone',
#  778: 'messages',
#  819: 'need',
#  59: 'batteries',
#  766: 'means',
#  352: 'enlightened',
#  54: 'barely',
#  1250: 'survive',
#  906: 'plan',
#  107: 'boring',
#  711: 'little',
#  765: 'meaning',
#  416: 'fine',
#  224: 'cool',
#  490: 'golden',
#  1032: 'rule',
#  835: 'numb',
#  1264: 'talk',
#  177: 'cheap',
#  485: 'god',
#  840: 'odd',
#  3: 'address',
#  1190: 'stars',
#  987: 'remind',
#  400: 'feeble',
#  756: 'man',
#  205: 'cologne',
#  1467: 'wouldnt',
#  197: 'closed',
#  723: 'longer',
#  18: 'analyzing',
#  1208: 'stop',
#  412: 'figure',
#  127: 'bring',
#  921: 'porch',
#  917: 'poet',
#  105: 'book',
#  1003: 'rhymes',
#  853: 'open',
#  666: 'knowing',
#  891: 'perfect',
#  1002: 'rhyme',
#  559: 'heavier',
#  1256: 'sweetest',
#  1212: 'story',
#  1268: 'tears',
#  1096: 'sheets',
#  441: 'footsteps',
#  528: 'hall',
#  746: 'mad',
#  1137: 'sleep',
#  120: 'breath',
#  419: 'finished',
#  626: 'instead',
#  829: 'ninetyeight',
#  274: 'degrees',
#  1077: 'separation',
#  1132: 'sitting',
#  1146: 'slowmo',
#  264: 'daylight',
#  831: 'nomad',
#  1018: 'rocket',
#  108: 'born',
#  163: 'cat',
#  1141: 'slight',
#  808: 'mothers',
#  712: 'live',
#  169: 'center',
#  1183: 'square',
#  816: 'mz',
#  631: 'isnt',
#  585: 'holding',
#  349: 'end',
#  418: 'finish',
#  1131: 'sit',
#  1327: 'traffic',
#  578: 'highway',
#  982: 'refuse',
#  1224: 'string',
#  617: 'incompletes',
#  679: 'lead',
#  989: 'remotely',
#  610: 'ii',
#  759: 'marry',
#  527: 'half',
#  1228: 'stuff',
#  357: 'eternity',
#  505: 'grave',
#  771: 'melody',
#  1406: 'wave',
#  300: 'dissipates',
#  359: 'evaporates',
#  937: 'promise',
#  1053: 'says',
#  1404: 'water',
#  1336: 'trigger',
#  1270: 'telephone',
#  1456: 'wondering',
#  203: 'coat',
#  429: 'flight',
#  1094: 'share',
#  1038: 'sadness',
#  1062: 'screen',
#  1473: 'wrongs',
#  58: 'battered',
#  410: 'fighters',
#  1203: 'stings',
#  830: 'nobodys',
#  11: 'air',
#  1318: 'took',
#  533: 'hang',
#  1484: 'youd',
#  448: 'fought',
#  1232: 'substitute',
#  475: 'girl',
#  950: 'puts',
#  206: 'color',
#  763: 'maze',
#  223: 'continually',
#  1202: 'steps',
#  394: 'fathers',
#  261: 'daughters',
#  737: 'lovers',
#  1188: 'standing',
#  1050: 'saw',
#  191: 'cleaning',
#  776: 'mess',
#  1158: 'soldier',
#  1397: 'warmth',
#  1454: 'womans',
#  70: 'behalf',
#  1419: 'weight',
#  67: 'begging',
#  614: 'imaginations',
#  1334: 'tricks',
#  686: 'leavings',
#  182: 'chest',
#  1076: 'separate',
#  975: 'really',
#  129: 'broken',
#  836: 'number',
#  1355: 'twice',
#  219: 'confirmation',
#  1359: 'understand',
#  595: 'horn',
#  4: 'adore',
#  586: 'hole',
#  248: 'cup',
#  888: 'people',
#  216: 'compromised',
#  556: 'hearts',
#  787: 'minds',
#  495: 'gotcha',
#  691: 'lets',
#  12: 'airports',
#  1162: 'someones',
#  96: 'blends',
#  1117: 'sigh',
#  212: 'coming',
#  1128: 'single',
#  1025: 'rose',
#  1426: 'wheel',
#  1463: 'working',
#  135: 'build',
#  684: 'leaves',
#  362: 'evergreen',
#  1067: 'season',
#  1068: 'seasons',
#  567: 'hello',
#  796: 'misunderstood',
#  61: 'beat',
#  302: 'distance',
#  820: 'neighbors',
#  1394: 'war',
#  1005: 'ribbons',
#  1343: 'trust',
#  1271: 'television',
#  621: 'information',
#  409: 'fight',
#  10: 'aint',
#  380: 'fair',
#  467: 'generation',
#  919: 'population',
#  627: 'interesting',
#  878: 'past',
#  1118: 'sign',
#  461: 'future',
#  1398: 'warned',
#  739: 'lovin',
#  66: 'beg',
#  464: 'garden',
#  967: 'rains',
#  1192: 'started',
#  1292: 'thought',
#  986: 'remembers',
#  174: 'changing',
#  978: 'recalls',
#  118: 'breaking',
#  970: 'rank',
#  1479: 'yelled',
#  733: 'loud',
#  75: 'believes',
#  857: 'ought',
#  342: 'easily',
#  72: 'belief',
#  31: 'armor',
#  560: 'heaviest',
#  1258: 'sword',
#  946: 'punching',
#  1360: 'underwater',
#  368: 'exhibition',
#  180: 'chemical',
#  1412: 'weapon',
#  963: 'ragin',
#  347: 'emptiness',
#  849: 'ones',
#  956: 'quietly',
#  1438: 'win',
#  411: 'fighting',
#  1248: 'surrendered',
#  1294: 'thousand',
#  1043: 'sand',
#  439: 'folded',
#  423: 'flag',
#  506: 'gravity',
#  320: 'dream',
#  1411: 'ways',
#  1452: 'woah',
#  1251: 'sustain',
#  1392: 'wanting',
#  492: 'gonna',
#  663: 'knees',
#  1261: 'taken',
#  774: 'men',
#  745: 'lying',
#  922: 'position',
#  551: 'hear',
#  709: 'listen',
#  865: 'pain',
#  1298: 'throws',
#  1351: 'turns',
#  48: 'bad',
#  824: 'news',
#  1307: 'timing',
#  272: 'defend',
#  1123: 'silver',
#  707: 'lining',
#  1433: 'whos',
#  541: 'hardly',
#  295: 'disappear',
#  487: 'goin',
#  1445: 'wire',
#  1391: 'wanted',
#  577: 'higher',
#  1275: 'testing',
#  1374: 'vultures',
#  1430: 'whispering',
#  1345: 'tryin',
#  656: 'kill',
#  1427: 'wheels',
#  1090: 'shake',
#  1035: 'running',
#  941: 'protect',
#  1133: 'situation',
#  851: 'ooh',
#  1424: 'whatcha',
#  97: 'blind',
#  1330: 'train',
#  1175: 'speed',
#  813: 'moving',
#  590: 'honestly',
#  468: 'generations',
#  689: 'length',
#  1486: 'young',
#  69: 'begun',
#  990: 'renegotiate',
#  789: 'minute',
#  634: 'itll',
#  1127: 'singing',
#  1122: 'silly',
#  1211: 'storm',
#  32: 'arms',
#  1048: 'save',
#  943: 'pulled',
#  386: 'false',
#  13: 'alarms',
#  309: 'doomed',
#  268: 'dear',
#  1145: 'slow',
#  254: 'dancing',
#  139: 'burning',
#  321: 'dreamed',
#  317: 'draw',
#  256: 'dare',
#  90: 'bitch',
#  606: 'hurt',
#  294: 'dirty',
#  681: 'learned',
#  22: 'anger',
#  1151: 'smiles',
#  1323: 'towering',
#  1101: 'shiny',
#  780: 'metallic',
#  948: 'purple',
#  952: 'queen',
#  640: 'jealousy',
#  354: 'envy',
#  1379: 'waits',
#  408: 'fiery',
#  509: 'green',
#  498: 'gown',
#  1153: 'sneers',
#  504: 'grassy',
#  698: 'lifegiving',
#  1405: 'waters',
#  502: 'granted',
#  537: 'happy',
#  1352: 'turquoise',
#  30: 'armies',
#  678: 'lay',
#  972: 'ready',
#  103: 'bold',
#  44: 'axis',
#  218: 'confident',
#  427: 'flashes',
#  1339: 'trophies',
#  358: 'euphoria',
#  856: 'orange',
#  257: 'daring',
#  1364: 'unsteady',
#  1480: 'yellow',
#  161: 'case',
#  770: 'mellow',
#  376: 'fact',
#  454: 'frightened',
#  346: 'emotions',
#  479: 'giving',
#  1265: 'talking',
#  323: 'dreaming',
#  1381: 'waking',
#  540: 'hardest',
#  1019: 'roll',
#  121: 'breathe',
#  247: 'crying',
#  1380: 'wake',
#  383: 'fall',
#  1026: 'roses',
#  599: 'hours',
#  784: 'midnight',
#  228: 'corners',
#  1081: 'set',
#  1263: 'taking',
#  5: 'advice',
#  39: 'assume',
#  993: 'repair',
#  1207: 'stood',
#  227: 'corner',
#  1439: 'wind',
#  99: 'blow',
#  128: 'brings',
#  116: 'brand',
#  741: 'luck',
#  874: 'park',
#  88: 'birds',
#  253: 'dance',
#  1254: 'sweaters',
#  977: 'reasons',
#  1125: 'sing',
#  736: 'lover',
#  443: 'forced',
#  592: 'hope',
#  826: 'nicer',
#  934: 'pride',
#  213: 'company',
#  325: 'dress',
#  701: 'lightning',
#  1223: 'strikes',
#  1236: 'sulfur',
#  104: 'bombs',
#  555: 'heartbreak',
#  ...}

# %% [markdown]
# Picking the ideal number of topics - this can be done by calculating the coherence score for each number of topics

# %%
# Now that we have the corpus (term-document matrix) and id2word (dictionary of location: term),
# we need to specify two other parameters as well - the number of topics and the number of passes
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=2, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.027*"love" + 0.015*"home" + 0.015*"heart" + 0.012*"dont" + 0.011*"feel" + 0.009*"way" + 0.009*"say" + 0.008*"waiting" + 0.008*"ill" + 0.008*"man"'),
#  (1,
#   '0.015*"dont" + 0.014*"love" + 0.012*"tell" + 0.011*"time" + 0.009*"life" + 0.009*"whiskey" + 0.008*"ill" + 0.008*"going" + 0.008*"come" + 0.008*"want"')]

# %%
# LDA for num_topics = 3
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=3, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.012*"whiskey" + 0.011*"love" + 0.011*"time" + 0.010*"youre" + 0.010*"dont" + 0.009*"changing" + 0.009*"gone" + 0.008*"thats" + 0.008*"water" + 0.008*"heart"'),
#  (1,
#   '0.033*"love" + 0.019*"dont" + 0.018*"home" + 0.013*"feel" + 0.013*"going" + 0.012*"say" + 0.011*"want" + 0.011*"come" + 0.009*"time" + 0.008*"right"'),
#  (2,
#   '0.018*"waiting" + 0.017*"tell" + 0.016*"heart" + 0.015*"ill" + 0.015*"life" + 0.014*"half" + 0.013*"world" + 0.010*"love" + 0.010*"body" + 0.009*"change"')]

# %%
# LDA for num_topics = 4
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=4, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.027*"love" + 0.015*"life" + 0.014*"time" + 0.013*"heart" + 0.013*"dont" + 0.011*"good" + 0.011*"way" + 0.010*"want" + 0.010*"half" + 0.010*"right"'),
#  (1,
#   '0.042*"love" + 0.023*"feel" + 0.016*"whiskey" + 0.015*"man" + 0.012*"water" + 0.012*"hold" + 0.011*"gone" + 0.010*"ill" + 0.009*"youre" + 0.009*"going"'),
#  (2,
#   '0.018*"waiting" + 0.014*"world" + 0.014*"dont" + 0.012*"change" + 0.012*"ooh" + 0.011*"moving" + 0.011*"time" + 0.010*"changing" + 0.010*"day" + 0.010*"leave"'),
#  (3,
#   '0.025*"home" + 0.017*"dont" + 0.016*"tell" + 0.015*"say" + 0.013*"ill" + 0.012*"love" + 0.011*"come" + 0.011*"right" + 0.010*"bed" + 0.010*"face"')]

# %% [markdown]
# ## Topic Modeling - Attempt #2 (Nouns Only)

# %% [markdown]
# One popular trick is to look only at terms that are from one part of speech (only nouns, only adjectives, etc.). Check out the UPenn tag set: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %%
# Let's create a function to pull out nouns from a string of text
from nltk import word_tokenize, pos_tag

def nouns(text):
    '''Given a string of text, tokenize the text and pull out only the nouns.'''
    is_noun = lambda pos: pos[:2] == 'NN'
    tokenized = word_tokenize(text)
    all_nouns = [word for (word, pos) in pos_tag(tokenized) if is_noun(pos)] 
    return ' '.join(all_nouns)

# %%
# Read in the cleaned data, before the CountVectorizer step
data_clean = pd.read_pickle('lyrics/corpus.pkl')
data_clean
# Out:
#                                                        Album  Year  Track #  \
# Title
# No Such Thing                               Room For Squares  2001        1
# Why Georgia                                 Room For Squares  2001        2
# My Stupid Mouth                             Room For Squares  2001        3
# Your Body Is A Wonderland                   Room For Squares  2001        4
# Neon                                        Room For Squares  2001        5
# ...                                                      ...   ...      ...
# "Moving On and Getting Over"       The Search For Everything  2017        8
# "Never on the Day You Leave"       The Search For Everything  2017        9
# "Rosie"                            The Search For Everything  2017       10
# "Roll It on Home"                  The Search For Everything  2017       11
# "You're Gonna Live Forever in Me"  The Search For Everything  2017       12
#
#                                                                Title  \
# Title
# No Such Thing                                          No Such Thing
# Why Georgia                                              Why Georgia
# My Stupid Mouth                                      My Stupid Mouth
# Your Body Is A Wonderland                  Your Body Is A Wonderland
# Neon                                                            Neon
# ...                                                              ...
# "Moving On and Getting Over"            "Moving On and Getting Over"
# "Never on the Day You Leave"            "Never on the Day You Leave"
# "Rosie"                                                      "Rosie"
# "Roll It on Home"                                  "Roll It on Home"
# "You're Gonna Live Forever in Me"  "You're Gonna Live Forever in Me"
#
#                                    Track Length  \
# Title
# No Such Thing                               231
# Why Georgia                                 269
# My Stupid Mouth                             225
# Your Body Is A Wonderland                   250
# Neon                                        262
# ...                                         ...
# "Moving On and Getting Over"                261
# "Never on the Day You Leave"                224
# "Rosie"                                     243
# "Roll It on Home"                           205
# "You're Gonna Live Forever in Me"           189
#
#                                                                               Lyrics
# Title
# No Such Thing                      welcome to the real world she said to me conde...
# Why Georgia                        i am driving up  in the kind of morning that l...
# My Stupid Mouth                    my stupid mouth has got me in trouble i said t...
# Your Body Is A Wonderland          we got the afternoon you got this room for two...
# Neon                               when sky blue gets dark enough to see the colo...
# ...                                                                              ...
# "Moving On and Getting Over"       moving on and getting over are not the same it...
# "Never on the Day You Leave"       no its never on the day you leave that you won...
# "Rosie"                            rosie come down and get the door for me im dru...
# "Roll It on Home"                  one last drink to drink wishful thinkin and th...
# "You're Gonna Live Forever in Me"  a great big bang and dinosaurs fiery raining m...
#
# [81 rows x 6 columns]

# %%
# Apply the nouns function to the transcripts to filter only on nouns
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

data_nouns = pd.DataFrame(data_clean.Lyrics.apply(nouns))
data_nouns
# Out:
# [nltk_data] Downloading package punkt to /Users/numalj/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/numalj/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
#                                                                               Lyrics
# Title
# No Such Thing                      welcome world seat life plot well i dreams kin...
# Why Georgia                        i kind morning afternoon gloom exits apartment...
# My Stupid Mouth                    mouth trouble i date dinner yesterday i change...
# Your Body Is A Wonderland          afternoon room thing left mile inch skin porce...
# Neon                               sky colors city trail ruby sunrise one shes st...
# ...                                                                              ...
# "Moving On and Getting Over"       mind i time friends i mind i time time fact yo...
# "Never on the Day You Leave"       day youll sound day grows time sing shell hair...
# "Rosie"                            rosie door i dream rain heart hand room tune r...
# "Roll It on Home"                  drink thinkin bar walls journey jukebox singin...
# "You're Gonna Live Forever in Me"  bang fiery meteors guarantee wait parts planet...
#
# [81 rows x 1 columns]

# %%
# Create a new document-term matrix using only nouns
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

# Re-add the additional stop words since we are recreating the document-term matrix
add_stop_words = ['just', 'im', 'like', 'know', 'got', 'oh']
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Recreate a document-term matrix with only nouns
cvn = CountVectorizer(stop_words=stop_words)
data_cvn = cvn.fit_transform(data_nouns.Lyrics)
data_dtmn = pd.DataFrame(data_cvn.toarray(), columns=cvn.get_feature_names())
data_dtmn.index = data_nouns.index
data_dtmn
# Out:
#                                    actors  address  advice  affair  afternoon  \
# Title
# No Such Thing                           0        0       0       0          0
# Why Georgia                             0        0       0       0          1
# My Stupid Mouth                         0        0       0       0          0
# Your Body Is A Wonderland               0        0       0       0          1
# Neon                                    0        0       0       0          0
# ...                                   ...      ...     ...     ...        ...
# "Moving On and Getting Over"            0        0       0       0          0
# "Never on the Day You Leave"            0        0       0       0          0
# "Rosie"                                 0        0       0       0          0
# "Roll It on Home"                       0        0       0       0          0
# "You're Gonna Live Forever in Me"       0        0       0       0          0
#
#                                    age  aint  air  airports  alarms  ...  \
# Title                                                                ...
# No Such Thing                        0     0    0         0       0  ...
# Why Georgia                          0     0    0         0       0  ...
# My Stupid Mouth                      0     0    0         0       0  ...
# Your Body Is A Wonderland            0     0    0         0       0  ...
# Neon                                 0     0    0         0       0  ...
# ...                                ...   ...  ...       ...     ...  ...
# "Moving On and Getting Over"         0     0    0         0       0  ...
# "Never on the Day You Leave"         0     0    0         0       0  ...
# "Rosie"                              0     0    0         0       0  ...
# "Roll It on Home"                    0     0    0         0       0  ...
# "You're Gonna Live Forever in Me"    0     0    0         0       0  ...
#
#                                    year  years  yellow  yes  yesterday  york  \
# Title
# No Such Thing                         1      0       0    0          0     0
# Why Georgia                           0      0       0    0          0     0
# My Stupid Mouth                       0      0       0    0          1     0
# Your Body Is A Wonderland             0      0       0    0          0     0
# Neon                                  0      0       0    0          0     0
# ...                                 ...    ...     ...  ...        ...   ...
# "Moving On and Getting Over"          0      0       0    0          0     0
# "Never on the Day You Leave"          0      0       0    0          0     0
# "Rosie"                               0      0       0    0          0     0
# "Roll It on Home"                     0      0       0    0          1     0
# "You're Gonna Live Forever in Me"     0      0       0    0          0     0
#
#                                    youd  youll  youre  youve
# Title
# No Such Thing                         0      0      0      3
# Why Georgia                           0      0      0      0
# My Stupid Mouth                       0      0      0      0
# Your Body Is A Wonderland             0      0      1      0
# Neon                                  0      0      0      0
# ...                                 ...    ...    ...    ...
# "Moving On and Getting Over"          0      0      0      1
# "Never on the Day You Leave"          0      2      0      0
# "Rosie"                               0      0      0      0
# "Roll It on Home"                     0      0      0      0
# "You're Gonna Live Forever in Me"     0      0      3      0
#
# [81 rows x 849 columns]

# %%
# Create the gensim corpus
corpusn = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmn.transpose()))

# Create the vocabulary dictionary
id2wordn = dict((v, k) for k, v in cvn.vocabulary_.items())

# %%
# Let's start with 2 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=2, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.027*"home" + 0.025*"way" + 0.024*"heart" + 0.020*"time" + 0.019*"man" + 0.015*"world" + 0.014*"water" + 0.013*"half" + 0.013*"love" + 0.010*"youre"'),
#  (1,
#   '0.029*"life" + 0.029*"love" + 0.019*"time" + 0.015*"heart" + 0.015*"dont" + 0.012*"thing" + 0.012*"home" + 0.009*"day" + 0.008*"youre" + 0.008*"world"')]

# %%
# Let's try topics = 3
ldan = models.LdaModel(corpus=corpusn, num_topics=3, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.032*"love" + 0.030*"time" + 0.023*"man" + 0.019*"way" + 0.019*"heart" + 0.019*"world" + 0.016*"water" + 0.014*"life" + 0.011*"thing" + 0.010*"ooh"'),
#  (1,
#   '0.056*"home" + 0.022*"way" + 0.015*"time" + 0.013*"face" + 0.013*"boy" + 0.013*"sadness" + 0.012*"repair" + 0.010*"life" + 0.010*"body" + 0.010*"ill"'),
#  (2,
#   '0.032*"heart" + 0.024*"half" + 0.023*"life" + 0.021*"dont" + 0.017*"love" + 0.014*"room" + 0.013*"bed" + 0.013*"youre" + 0.012*"home" + 0.011*"world"')]

# %%
# Let's try 4 topics
ldan = models.LdaModel(corpus=corpusn, num_topics=4, id2word=id2wordn, passes=10)
ldan.print_topics()
# Out:
# [(0,
#   '0.064*"home" + 0.034*"man" + 0.030*"life" + 0.016*"water" + 0.014*"whiskey" + 0.013*"time" + 0.013*"sadness" + 0.012*"repair" + 0.012*"face" + 0.010*"day"'),
#  (1,
#   '0.028*"dont" + 0.023*"ooh" + 0.023*"life" + 0.020*"world" + 0.019*"bed" + 0.018*"daughters" + 0.013*"assassin" + 0.013*"head" + 0.011*"thing" + 0.010*"door"'),
#  (2,
#   '0.052*"love" + 0.028*"time" + 0.026*"way" + 0.017*"youre" + 0.015*"body" + 0.014*"day" + 0.011*"aint" + 0.010*"age" + 0.010*"thing" + 0.009*"life"'),
#  (3,
#   '0.055*"heart" + 0.026*"half" + 0.022*"world" + 0.022*"time" + 0.021*"way" + 0.018*"love" + 0.013*"dont" + 0.012*"helpless" + 0.012*"mind" + 0.011*"heartbreak"')]

# %% [markdown]
# ## Topic Modeling - Attempt #3 (Nouns and Adjectives)

# %%
# Let's create a function to pull out nouns from a string of text
def nouns_adj(text):
    '''Given a string of text, tokenize the text and pull out only the nouns and adjectives.'''
    is_noun_adj = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ'
    tokenized = word_tokenize(text)
    nouns_adj = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj(pos)] 
    return ' '.join(nouns_adj)

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns_adj = pd.DataFrame(data_clean.Lyrics.apply(nouns_adj))
data_nouns_adj
# Out:
#                                                                               Lyrics
# Title
# No Such Thing                      welcome real world seat life plot black white ...
# Why Georgia                        i kind morning afternoon gloom exits apartment...
# My Stupid Mouth                    stupid mouth trouble i much date dinner yester...
# Your Body Is A Wonderland          afternoon room thing ive left mile inch skin p...
# Neon                               sky blue dark colors city trail ruby red diamo...
# ...                                                                              ...
# "Moving On and Getting Over"       same im older cant mind i time friends long i ...
# "Never on the Day You Leave"       day goodbye youll old familiar sound day grows...
# "Rosie"                            rosie door rosie i dream january rain heart ha...
# "Roll It on Home"                  last drink wishful thinkin bar walls journey j...
# "You're Gonna Live Forever in Me"  great big bang fiery meteors i guarantee wait ...
#
# [81 rows x 1 columns]

# %%
# Re-add the additional stop words since we are recreating the document-term matrix
add_stop_words = ['just', 'im', 'like', 'know', 'got', 'oh','dont', 'ill']
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Create a new document-term matrix using only nouns and adjectives, also remove common words with max_df
cvna = CountVectorizer(stop_words=stop_words, max_df=.8, min_df=0.05)
data_cvna = cvna.fit_transform(data_nouns_adj.Lyrics)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.get_feature_names())
data_dtmna.index = data_nouns_adj.index
data_dtmna
# Out:
#                                    aint  alive  baby  bed  best  big  black  \
# Title
# No Such Thing                         0      1     0    0     1    0      1
# Why Georgia                           0      0     0    0     0    0      0
# My Stupid Mouth                       0      0     0    0     0    0      0
# Your Body Is A Wonderland             0      0     0    1     0    2      0
# Neon                                  0      0     0    0     0    0      0
# ...                                 ...    ...   ...  ...   ...  ...    ...
# "Moving On and Getting Over"          0      0     1    0     0    0      0
# "Never on the Day You Leave"          0      0     0    0     0    0      0
# "Rosie"                               0      0     0    0     0    0      0
# "Roll It on Home"                     0      0     0    0     1    0      0
# "You're Gonna Live Forever in Me"     0      0     0    0     0    1      0
#
#                                    blue  broken  cause  ...  ways  white  \
# Title                                                   ...
# No Such Thing                         0       0      0  ...     0      2
# Why Georgia                           0       0      0  ...     0      0
# My Stupid Mouth                       0       0      0  ...     0      0
# Your Body Is A Wonderland             0       0      0  ...     0      0
# Neon                                  1       0      0  ...     0      1
# ...                                 ...     ...    ...  ...   ...    ...
# "Moving On and Getting Over"          0       0      2  ...     0      0
# "Never on the Day You Leave"          0       0      0  ...     0      0
# "Rosie"                               0       0      0  ...     0      0
# "Roll It on Home"                     0       0      0  ...     0      0
# "You're Gonna Live Forever in Me"     0       0      0  ...     0      0
#
#                                    wont  words  world  wrong  yeah  youll  \
# Title
# No Such Thing                         0      0      4      0     0      0
# Why Georgia                           0      0      0      0     0      0
# My Stupid Mouth                       0      0      0      1     0      0
# Your Body Is A Wonderland             0      0      0      0     0      0
# Neon                                  0      0      0      0     0      0
# ...                                 ...    ...    ...    ...   ...    ...
# "Moving On and Getting Over"          0      0      0      1     0      0
# "Never on the Day You Leave"          0      0      0      0     0      2
# "Rosie"                               0      1      0      0     0      0
# "Roll It on Home"                     0      0      0      0     0      0
# "You're Gonna Live Forever in Me"     0      0      0      0     0      0
#
#                                    youre  youve
# Title
# No Such Thing                          0      3
# Why Georgia                            0      0
# My Stupid Mouth                        0      0
# Your Body Is A Wonderland              1      0
# Neon                                   0      0
# ...                                  ...    ...
# "Moving On and Getting Over"           0      1
# "Never on the Day You Leave"           0      0
# "Rosie"                                0      0
# "Roll It on Home"                      0      0
# "You're Gonna Live Forever in Me"      3      0
#
# [81 rows x 81 columns]

# %% [markdown]
# From vectorizer documentation
# **max_dffloat in range [0.0, 1.0] or int (default=1.0):**
# When building the vocabulary ignore terms that have a document frequency strictly higher than the given threshold (corpus-specific stop words). If float, the parameter represents a proportion of documents, integer absolute counts. This parameter is ignored if vocabulary is not None.
#
# **min_dffloat in range [0.0, 1.0] or int (default=1)**
# When building the vocabulary ignore terms that have a document frequency strictly lower than the given threshold. This value is also called cut-off in the literature. If float, the parameter represents a proportion of documents, integer absolute counts. This parameter is ignored if vocabulary is not None.

# %%
# Create the gensim corpus
corpusna = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmna.transpose()))

# Create the vocabulary dictionary
id2wordna = dict((v, k) for k, v in cvna.vocabulary_.items())

# %%
# Let's start with 2 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=2, id2word=id2wordna, passes=100)
ldana.print_topics()
# Out:
# [(0,
#   '0.015*"world" + 0.011*"half" + 0.009*"goodbye" + 0.007*"body" + 0.007*"bed" + 0.006*"long" + 0.006*"sadness" + 0.006*"baby" + 0.006*"bold" + 0.005*"yeah"'),
#  (1,
#   '0.023*"whiskey" + 0.018*"water" + 0.012*"face" + 0.012*"olivia" + 0.011*"helpless" + 0.009*"age" + 0.009*"gon" + 0.009*"weekend" + 0.008*"aint" + 0.008*"days"')]

# %%
# Let's try 3 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=100)
ldana.print_topics()
# Out:
# [(0,
#   '0.021*"world" + 0.013*"whiskey" + 0.010*"water" + 0.009*"body" + 0.008*"bed" + 0.008*"yeah" + 0.008*"sadness" + 0.007*"days" + 0.007*"face" + 0.007*"baby"'),
#  (1,
#   '0.025*"half" + 0.017*"goodbye" + 0.012*"heartbreak" + 0.008*"hearts" + 0.008*"long" + 0.008*"assassin" + 0.008*"warfare" + 0.007*"youll" + 0.007*"night" + 0.006*"pain"'),
#  (2,
#   '0.019*"helpless" + 0.016*"gon" + 0.016*"weekend" + 0.015*"roll" + 0.013*"honey" + 0.010*"water" + 0.010*"wave" + 0.010*"blood" + 0.008*"nobodys" + 0.007*"rosie"')]

# %%
# Let's try 3 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=100)
ldana.print_topics()
# Out:
# [(0,
#   '0.038*"whiskey" + 0.022*"water" + 0.020*"olivia" + 0.019*"face" + 0.015*"age" + 0.013*"aint" + 0.013*"days" + 0.012*"boy" + 0.012*"worry" + 0.012*"verb"'),
#  (1,
#   '0.035*"half" + 0.024*"goodbye" + 0.016*"heartbreak" + 0.012*"assassin" + 0.012*"warfare" + 0.011*"night" + 0.011*"hearts" + 0.009*"fight" + 0.009*"lovers" + 0.009*"long"'),
#  (2,
#   '0.016*"world" + 0.008*"body" + 0.007*"baby" + 0.007*"sadness" + 0.007*"bed" + 0.006*"bold" + 0.006*"old" + 0.006*"gon" + 0.006*"yeah" + 0.005*"neon"')]

# %%
# Let's try 4 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=100)
ldana.print_topics()
# Out:
# [(0,
#   '0.025*"world" + 0.015*"bold" + 0.014*"gon" + 0.013*"repair" + 0.013*"helpless" + 0.012*"baby" + 0.011*"weekend" + 0.010*"water" + 0.010*"roll" + 0.009*"train"'),
#  (1,
#   '0.016*"whiskey" + 0.015*"half" + 0.011*"face" + 0.011*"goodbye" + 0.010*"water" + 0.008*"bed" + 0.008*"sadness" + 0.008*"olivia" + 0.008*"aint" + 0.008*"free"'),
#  (2,
#   '0.001*"feet" + 0.001*"older" + 0.001*"safe" + 0.001*"think" + 0.001*"clothes" + 0.001*"sea" + 0.001*"hair" + 0.001*"youve" + 0.001*"lights" + 0.001*"sky"'),
#  (3,
#   '0.016*"neon" + 0.013*"body" + 0.013*"world" + 0.012*"living" + 0.009*"hands" + 0.009*"wonderland" + 0.008*"great" + 0.008*"shes" + 0.008*"long" + 0.008*"indoors"')]

# %% [markdown]
# The topics aren't too convincing. Let's see if the albums belong to a general topic

# %% [markdown]
# ## Topic Modeling on Albums - Nouns and Adjectives

# %%
# Read in the cleaned data, before the CountVectorizer step
data_clean_album = pd.read_pickle('lyrics/album_corpus.pkl')
data_clean_album
# Out:
#                           Album  Year  Total Album Length  Num_of_Tracks  \
# Year
# 2001           Room For Squares  2001                3259             13
# 2003             Heavier Things  2003                2780             10
# 2006                  Continuum  2006                2987             12
# 2009             Battle Studies  2009                2798             11
# 2012            Born And Raised  2012                2799             12
# 2013            Paradise Valley  2013                2410             11
# 2017  The Search For Everything  2017                2629             12
#
#                                                  Lyrics
# Year
# 2001  welcome to the real world she said to me conde...
# 2003  i worry i weigh three times my body i worry i ...
# 2006  me and all my friends were all misunderstood t...
# 2009  lightning strikes inside my chest to keep me u...
# 2012   ooh ooh ooh ooh close your eyes and clone you...
# 2013   dear marie tell me what it was i used to be d...
# 2017  i still feel like your man i still feel like y...

# %%
# Let's create a function to pull out nouns from a string of text
def nouns_adj(text):
    '''Given a string of text, tokenize the text and pull out only the nouns and adjectives.'''
    is_noun_adj = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ'
    tokenized = word_tokenize(text)
    nouns_adj = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj(pos)] 
    return ' '.join(nouns_adj)

# %%
# Apply the nouns function to the transcripts to filter only on nouns
data_nouns_adj = pd.DataFrame(data_clean_album.Lyrics.apply(nouns_adj))
data_nouns_adj
# Out:
#                                                  Lyrics
# Year
# 2001  welcome real world seat life plot black white ...
# 2003  i i times body i i fear morning calm i rock ca...
# 2006  friends misunderstood nothing way everything t...
# 2009  strikes chest night dream ways pain clouds sul...
# 2012  ooh ooh ooh eyes clone heart army innocence ev...
# 2013  dear marie dear marie youre road i cant boy fi...
# 2017  i man i man i i i man prettiest girl room come...

# %%
# Create a new document-term matrix using only nouns
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

# Re-add the additional stop words since we are recreating the document-term matrix
add_stop_words = ['just', 'im', 'like', 'know', 'got', 'oh','dont', 'ill', 'ooh']
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Create a new document-term matrix using only nouns and adjectives, also remove common words with max_df
cvna = CountVectorizer(stop_words=stop_words, max_df=.8, min_df=0.05)
data_cvna = cvna.fit_transform(data_nouns_adj.Lyrics)
data_dtmna = pd.DataFrame(data_cvna.toarray(), columns=cvna.get_feature_names())
data_dtmna.index = data_nouns_adj.index
data_dtmna
# Out:
#       actors  address  advice  affair  afternoon  age  aint  air  airports  \
# Year
# 2001       1        0       0       0          2    0     0    0         0
# 2003       0        1       0       0          2    0     0    1         1
# 2006       0        0       3       0          0    0     3    0         0
# 2009       0        0       0       1          0    0     0    2         0
# 2012       0        0       0       0          0   10     9    1         0
# 2013       0        0       0       0          0    1     4    0         0
# 2017       0        0       0       0          0    0     0    0         0
#
#       alarms  ...  years  yellow  yes  yesterday  york  youd  youll  young  \
# Year          ...
# 2001       0  ...      1       0    0          1     0     0      1      0
# 2003       0  ...      0       0    1          0     0     1      0      0
# 2006       1  ...      0       1    0          0     0     0      2      2
# 2009       0  ...      0       1    1          1     3     0      2      2
# 2012       0  ...      0       0    0          1     1     1      0      0
# 2013       0  ...      1       0    0          0     0     1      5      0
# 2017       0  ...      0       0    0          1     0     0      2      2
#
#       younger  youve
# Year
# 2001        0      3
# 2003        0      0
# 2006        0      0
# 2009        1      0
# 2012        0      1
# 2013        0      3
# 2017        0      1
#
# [7 rows x 1005 columns]

# %%
from gensim import matutils, models
import scipy.sparse

# Create the gensim corpus
corpusna = matutils.Sparse2Corpus(scipy.sparse.csr_matrix(data_dtmna.transpose()))

# Create the vocabulary dictionary
id2wordna = dict((v, k) for k, v in cvna.vocabulary_.items())

# %%
# Let's start with 2 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=2, id2word=id2wordna, passes=500)
ldana.print_topics()
# Out:
# [(0,
#   '0.017*"half" + 0.016*"world" + 0.011*"goodbye" + 0.009*"bold" + 0.008*"repair" + 0.008*"war" + 0.008*"hearts" + 0.007*"heartbreak" + 0.007*"train" + 0.006*"pain"'),
#  (1,
#   '0.013*"whiskey" + 0.011*"water" + 0.009*"world" + 0.008*"body" + 0.007*"face" + 0.007*"days" + 0.007*"sadness" + 0.007*"bed" + 0.007*"olivia" + 0.006*"neon"')]

# %%
# Let's start with 3 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=3, id2word=id2wordna, passes=500)
ldana.print_topics()
# Out:
# [(0,
#   '0.019*"sadness" + 0.016*"bed" + 0.015*"daughters" + 0.012*"mothers" + 0.012*"someday" + 0.010*"yeah" + 0.010*"body" + 0.010*"oooooo" + 0.008*"bigger" + 0.008*"wheel"'),
#  (1,
#   '0.022*"world" + 0.009*"bold" + 0.008*"neon" + 0.008*"repair" + 0.007*"train" + 0.007*"body" + 0.006*"shes" + 0.006*"trust" + 0.006*"baby" + 0.006*"living"'),
#  (2,
#   '0.020*"whiskey" + 0.018*"half" + 0.016*"water" + 0.013*"face" + 0.013*"goodbye" + 0.010*"olivia" + 0.009*"free" + 0.009*"helpless" + 0.008*"night" + 0.008*"heartbreak"')]

# %%
# Let's start with 4 topics
ldana = models.LdaModel(corpus=corpusna, num_topics=4, id2word=id2wordna, passes=500)
ldana.print_topics()
# Out:
# [(0,
#   '0.026*"world" + 0.015*"bold" + 0.013*"repair" + 0.011*"train" + 0.010*"baby" + 0.010*"trust" + 0.009*"lovin" + 0.008*"old" + 0.008*"youll" + 0.008*"burning"'),
#  (1,
#   '0.040*"half" + 0.027*"goodbye" + 0.019*"heartbreak" + 0.014*"warfare" + 0.014*"assassin" + 0.012*"hearts" + 0.012*"night" + 0.010*"fight" + 0.010*"long" + 0.010*"lovers"'),
#  (2,
#   '0.011*"neon" + 0.011*"helpless" + 0.010*"gon" + 0.010*"body" + 0.010*"weekend" + 0.010*"world" + 0.009*"long" + 0.009*"living" + 0.009*"roll" + 0.008*"honey"'),
#  (3,
#   '0.026*"whiskey" + 0.016*"water" + 0.014*"sadness" + 0.014*"olivia" + 0.013*"face" + 0.012*"bed" + 0.011*"daughters" + 0.010*"age" + 0.009*"days" + 0.009*"yeah"')]

# %% [markdown]
# Looking at the three topic classification, seems like the topics are:
# 1.  Family (Mothers and Daughters)
# 2.  Living Life
# 3.  Breakups

# %% [markdown]
# ## Topic Modeling - NMF (Non-negative Matrix Factorization)

# %%
from gensim.models import ldamodel
import gensim.corpora;
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer;
from sklearn.decomposition import NMF;
from sklearn.preprocessing import normalize;
import pickle;

# %%
# Read in the cleaned data, before the CountVectorizer step
data_clean_songs = pd.read_pickle('lyrics/corpus.pkl')
data_clean_songs
# Out:
#                                                        Album  Year  Track #  \
# Title
# No Such Thing                               Room For Squares  2001        1
# Why Georgia                                 Room For Squares  2001        2
# My Stupid Mouth                             Room For Squares  2001        3
# Your Body Is A Wonderland                   Room For Squares  2001        4
# Neon                                        Room For Squares  2001        5
# ...                                                      ...   ...      ...
# "Moving On and Getting Over"       The Search For Everything  2017        8
# "Never on the Day You Leave"       The Search For Everything  2017        9
# "Rosie"                            The Search For Everything  2017       10
# "Roll It on Home"                  The Search For Everything  2017       11
# "You're Gonna Live Forever in Me"  The Search For Everything  2017       12
#
#                                                                Title  \
# Title
# No Such Thing                                          No Such Thing
# Why Georgia                                              Why Georgia
# My Stupid Mouth                                      My Stupid Mouth
# Your Body Is A Wonderland                  Your Body Is A Wonderland
# Neon                                                            Neon
# ...                                                              ...
# "Moving On and Getting Over"            "Moving On and Getting Over"
# "Never on the Day You Leave"            "Never on the Day You Leave"
# "Rosie"                                                      "Rosie"
# "Roll It on Home"                                  "Roll It on Home"
# "You're Gonna Live Forever in Me"  "You're Gonna Live Forever in Me"
#
#                                    Track Length  \
# Title
# No Such Thing                               231
# Why Georgia                                 269
# My Stupid Mouth                             225
# Your Body Is A Wonderland                   250
# Neon                                        262
# ...                                         ...
# "Moving On and Getting Over"                261
# "Never on the Day You Leave"                224
# "Rosie"                                     243
# "Roll It on Home"                           205
# "You're Gonna Live Forever in Me"           189
#
#                                                                               Lyrics
# Title
# No Such Thing                      welcome to the real world she said to me conde...
# Why Georgia                        i am driving up  in the kind of morning that l...
# My Stupid Mouth                    my stupid mouth has got me in trouble i said t...
# Your Body Is A Wonderland          we got the afternoon you got this room for two...
# Neon                               when sky blue gets dark enough to see the colo...
# ...                                                                              ...
# "Moving On and Getting Over"       moving on and getting over are not the same it...
# "Never on the Day You Leave"       no its never on the day you leave that you won...
# "Rosie"                            rosie come down and get the door for me im dru...
# "Roll It on Home"                  one last drink to drink wishful thinkin and th...
# "You're Gonna Live Forever in Me"  a great big bang and dinosaurs fiery raining m...
#
# [81 rows x 6 columns]

# %%
cv = CountVectorizer(stop_words='english', analyzer='word', max_features=5000)
song_cv = cv.fit_transform(data_clean_songs.Lyrics)
song_dtm = pd.DataFrame(song_cv.toarray(), columns=cv.get_feature_names())
song_dtm.index = data_clean_songs.index
song_dtm
# Out:
#                                    accepted  act  actors  address  adore  \
# Title
# No Such Thing                             0    0       0        0      0
# Why Georgia                               0    0       0        0      0
# My Stupid Mouth                           0    0       0        0      0
# Your Body Is A Wonderland                 0    0       0        0      0
# Neon                                      0    0       0        0      0
# ...                                     ...  ...     ...      ...    ...
# "Moving On and Getting Over"              0    0       0        0      0
# "Never on the Day You Leave"              0    0       0        0      0
# "Rosie"                                   0    0       0        0      0
# "Roll It on Home"                         0    0       0        0      0
# "You're Gonna Live Forever in Me"         0    0       0        0      0
#
#                                    advice  affair  afternoon  age  ago  ...  \
# Title                                                                   ...
# No Such Thing                           0       0          0    0    0  ...
# Why Georgia                             0       0          1    0    0  ...
# My Stupid Mouth                         0       0          0    0    0  ...
# Your Body Is A Wonderland               0       0          1    0    0  ...
# Neon                                    0       0          0    0    0  ...
# ...                                   ...     ...        ...  ...  ...  ...
# "Moving On and Getting Over"            0       0          0    0    0  ...
# "Never on the Day You Leave"            0       0          0    0    0  ...
# "Rosie"                                 0       0          0    0    0  ...
# "Roll It on Home"                       0       0          0    0    0  ...
# "You're Gonna Live Forever in Me"       0       0          0    0    0  ...
#
#                                    yellow  yes  yesterday  york  youd  youll  \
# Title
# No Such Thing                           0    0          0     0     0      0
# Why Georgia                             0    0          0     0     0      0
# My Stupid Mouth                         0    0          1     0     0      0
# Your Body Is A Wonderland               0    0          0     0     0      0
# Neon                                    0    0          0     0     0      0
# ...                                   ...  ...        ...   ...   ...    ...
# "Moving On and Getting Over"            0    0          0     0     0      0
# "Never on the Day You Leave"            0    0          0     0     1      2
# "Rosie"                                 0    0          0     0     0      0
# "Roll It on Home"                       0    0          1     0     0      0
# "You're Gonna Live Forever in Me"       0    0          0     0     0      0
#
#                                    young  younger  youre  youve
# Title
# No Such Thing                          0        0      0      3
# Why Georgia                            0        0      0      0
# My Stupid Mouth                        0        0      0      0
# Your Body Is A Wonderland              0        0      1      0
# Neon                                   0        0      0      0
# ...                                  ...      ...    ...    ...
# "Moving On and Getting Over"           0        0      0      2
# "Never on the Day You Leave"           0        0      0      0
# "Rosie"                                0        0      0      0
# "Roll It on Home"                      0        0      0      1
# "You're Gonna Live Forever in Me"      0        0      4      0
#
# [81 rows x 1500 columns]

# %%
transformer = TfidfTransformer(smooth_idf=False)
tfidf_song_cv = transformer.fit_transform(song_cv)

# %%
# Normalize
xtfidf_norm = normalize(tfidf_song_cv, norm='l1', axis=1)

# %%
# Num of topics
num_topics = 4

#obtain a NMF model.
model = NMF(n_components=num_topics, init='nndsvd');
#fit the model
model.fit(xtfidf_norm)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init='nndsvd', l1_ratio=0.0, max_iter=200,
#     n_components=4, random_state=None, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
def get_nmf_topics(model, n_top_words):
    
    #the word ids obtained need to be reverse-mapped to the words so we can print the topic names.
    feat_names = cv.get_feature_names()
    
    word_dict = {};
    for i in range(num_topics):
        
        #for each topic, obtain the largest values, and add the words they map to into the dictionary.
        words_ids = model.components_[i].argsort()[:-20 - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
get_nmf_topics(model, 20)
# Out:
#    Topic # 01 Topic # 02 Topic # 03  Topic # 04 Topic # 05 Topic # 06
# 0        love     olivia         im    changing    goodbye       feel
# 1        verb       like   helpless      hearts        say        man
# 2        aint   thinking       tell       young        try       like
# 3    dreaming        man     moving         run       gone       babe
# 4       thing      steal    waiting         old       want       wash
# 5          oh       gets        got       round      break       know
# 6        hold       time     change      senses      heart    whiskey
# 7       youve      taken      going      follow      going      water
# 8        yeah         im       time       apart     wildly      cause
# 9       youre      sleep        ill      fences      plane       dont
# 10       stop     trying       dont        rope     landed         id
# 11     coming       look      heart     stopped  thrashing      think
# 12       make         id       life         ear        let      gonna
# 13        saw       need      world     reminds     giving      blood
# 14       dont      world       just       shell      songs       come
# 15    weekend     theres       home         fun     ticket       home
# 16       know       away    getting  whispering      voice      early
# 17       hard       love        way        went     bought      party
# 18    despite       yeah     theres   wondering        bed    shampoo
# 19     excuse       door       baby         sun      quiet  prettiest
